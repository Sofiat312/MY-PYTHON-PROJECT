# %%
from IPython.display import display
from PIL import Image
img = Image.open("youtube.jpg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x281>

# %% [markdown]
# # Project Title : Top 100 YouTube Channels in 2024

# %% [markdown]
# # About Dataset
#
# This dataset showcases the top 100 YouTube channels in 2024, including key metrics such as subscribers, total views, and video count. It has been manually curated to provide a snapshot of the leading channels as of December 2024. The data reflects the performance of channels across various genres, from entertainment to educational content, offering insights into the most influential creators of the year. This data is useful for marketers, content creators, and data scientists who want to analyze trends, audience engagement, and growth strategies of top YouTube influencers. By examining these metrics, users can gain valuable insights into content creation, viewer preferences, and platform dynamics. The dataset is based on publicly available YouTube statistics and third-party platforms, ensuring transparency and accuracy.

# %%
# Libraries to use for Data cleaning, numbers, and plotting Charts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Dataset
youtube = pd.read_csv('YOUTUBE CHANNELS DATASET.csv')

# %%
youtube
# Out:
#      Ranking                  Username Subscribers  Uploads            Views  \
# 0        1.0                   MrBeast        336M      838   66,853,633,536
# 1        2.0                  T-Series        281M   22,313  277,242,795,553
# 2        3.0  Cocomelon-Nursery Rhymes        186M     1370  194,361,752,276
# 3        4.0            Youtube Movies        185M        0                0
# 4        5.0                 Set India        180M  148,727  172,709,029,653
# ..       ...                       ...         ...      ...              ...
# 96      97.0                Voce Sabia         46M    1,714    8,180,068,059
# 97      98.0                Katy Perry       45.6M      170   27,616,850,074
# 98      99.0             Speed Records       45.5M   11,880   30,587,436,800
# 99     100.0                     Zhong       45.5M    1,861   17,998,163,730
# 100      NaN                       NaN         NaN      NaN              NaN
#
#     Country
# 0        US
# 1        IN
# 2        US
# 3       NaN
# 4        IN
# ..      ...
# 96       BR
# 97       US
# 98       IN
# 99       US
# 100     NaN
#
# [101 rows x 6 columns]

# %%
# str.replace('M',''): Removes the letter 'M' from the values.
# .astype(float): Converts the remaining numeric string to a float.
# * 1_000_000: Converts the number to its actual integer value by multiplying by one million.
youtube['Subscribers'] = youtube['Subscribers'].str.replace('M','').astype(float) * 1_000_000

# %%
# Clean 'Uploads', and 'Views' columns
for col in ['Uploads', 'Views']:
    if col in youtube.columns:
        youtube[col]= pd.to_numeric(youtube[col].astype(str).str.replace(',',''), errors='coerce')

# %%
print(youtube.to_string())
# Out:
#      Ranking                         Username  Subscribers   Uploads         Views Country
# 0        1.0                          MrBeast  336000000.0     838.0  6.685363e+10      US
# 1        2.0                         T-Series  281000000.0   22313.0  2.772428e+11      IN
# 2        3.0         Cocomelon-Nursery Rhymes  186000000.0    1370.0  1.943618e+11      US
# 3        4.0                   Youtube Movies  185000000.0       0.0  0.000000e+00     NaN
# 4        5.0                        Set India  180000000.0  148727.0  1.727090e+11      IN
# 5        6.0                      Vlad & Niki  129000000.0     796.0  9.929150e+10      US
# 6        7.0                  Kids Diana Show  128000000.0    1282.0  1.089879e+11      US
# 7        8.0                      Like Nastya  124000000.0     918.0  1.081285e+11      US
# 8        9.0                            Music  121000000.0       0.0  0.000000e+00     NaN
# 9       10.0                Zee Music Company  112000000.0   12787.0  7.209135e+10      IN
# 10      11.0                        PewDiePie  110000000.0    4800.0  2.945393e+10      JP
# 11      12.0                              WWE  106000000.0   80964.0  9.016718e+10     NaN
# 12      13.0                     Stokes Twins  102000000.0     335.0  1.613931e+10      US
# 13      14.0                        Goldmines  101000000.0    9421.0  2.993637e+10      IN
# 14      15.0                         Sony SAB   97700000.0   94136.0  1.231728e+11      IN
# 15      16.0                        Blackpink   95400000.0     603.0  3.750283e+10      KR
# 16      17.0                        ChuChu Tv   94300000.0     832.0  5.326542e+10      IN
# 17      18.0                           Gaming   92900000.0       0.0  0.000000e+00     NaN
# 18      19.0                           Zee TV   86200000.0  190672.0  9.756699e+10      IN
# 19      20.0                  5-Minute Crafts   81100000.0    7391.0  2.790758e+10      US
# 20      21.0                        BANGTANTY   79400000.0    2674.0  2.416170e+10      KR
# 21      22.0  Baby Shark - Pinkfong Kids Song   79300000.0    3399.0  4.749789e+10      US
# 22      23.0                        Colors TV   77600000.0  179052.0  7.649003e+10      IN
# 23      24.0                      HYBE LABELS   76200000.0    2253.0  3.727927e+10      KR
# 24      25.0                           Sports   74700000.0       0.0  0.000000e+00     NaN
# 25      26.0                    Justin Bieber   74400000.0     249.0  3.363673e+10      CA
# 26      27.0                           KIMPRO   73300000.0    3580.0  5.671546e+10      KR
# 27      28.0            T-Series Bhakti Sagar   72600000.0   29140.0  3.718563e+10      IN
# 28      29.0                     UR.Cristiano   71700000.0      80.0  7.212288e+08      PT
# 29      30.0                               A4   71500000.0     971.0  3.148760e+10      US
# 30      31.0                    Tips Official   71000000.0    6859.0  4.317125e+10      IN
# 31      32.0             Shemaroo Filmi Gaane   70300000.0    8988.0  3.098245e+10      IN
# 32      33.0                 Alan Chikin Chow   70000000.0    1413.0  4.893576e+10      US
# 33      34.0        ZAMZAM ELECTRONIC TRADING   69400000.0   19224.0  3.423727e+10      AE
# 34      35.0                          Aaj Tak   68700000.0  415087.0  3.555227e+10      IN
# 35      36.0                    Toys & Colors   68300000.0    1396.0  8.239180e+10      US
# 36      37.0                  Canal Kondzilla   67500000.0    3014.0  3.892369e+10      BR
# 37      38.0                El Reino Infantil   67100000.0    1667.0  6.404265e+10      AR
# 38      39.0                  Infobells-Hindi   66800000.0     731.0  3.966141e+10      IN
# 39      40.0                       Wave Music   63700000.0   20481.0  4.398011e+10      IN
# 40      41.0                      EminemMusic   63400000.0     196.0  3.225630e+10     NaN
# 41      42.0                      HAR PAL GEO   62900000.0  152148.0  6.418488e+10      PK
# 42      43.0                       MovieClips   62900000.0   41711.0  6.418422e+10      US
# 43      44.0                 Sony Music India   62900000.0    5941.0  3.251887e+10      IN
# 44      45.0                              YRF   62900000.0    4333.0  4.470236e+10      IN
# 45      46.0             KL BRO Biju R ithvik   62800000.0    2873.0  5.438517e+10      IN
# 46      47.0                       Mark Rober   60800000.0     187.0  8.956227e+09      US
# 47      48.0                     Dude Perfect   60600000.0     463.0  1.800590e+10      US
# 48      49.0                     Taylor Swift   60400000.0     285.0  3.766317e+10      US
# 49      50.0                    Fede Vigevani   60000000.0    1435.0  1.763658e+10      MX
# 50      51.0                   ARY Digital HD   59900000.0  155545.0  5.935571e+10      PK
# 51      52.0                     LooLoo Kids    59300000.0     933.0  3.660360e+10      US
# 52      53.0            Billion Surprise Toys   57600000.0    1221.0  1.060295e+10      US
# 53      54.0                       Marshmello   57500000.0     508.0  1.638922e+10      US
# 54      55.0                   YOLO AVENTURAS   56500000.0    2655.0  1.976380e+10      MX
# 55      56.0                        Shemaroo    56300000.0   13166.0  2.566960e+10      IN
# 56      57.0                        PANDA BOL   55900000.0    1143.0  2.524301e+10      IT
# 57      58.0                       Alejo lgoa   55900000.0    1158.0  2.025569e+10      AR
# 58      59.0                       Ed Sheeran   55600000.0     538.0  3.342412e+10      GB
# 59      60.0                    Ariana Grande   55100000.0     214.0  2.757534e+10      US
# 60      61.0                    shripraashant   53900000.0   11966.0  3.237976e+09      IN
# 61      62.0                    Billie Eilish   53900000.0     142.0  1.759971e+10      US
# 62      63.0                       Get Movies   53600000.0    3468.0  3.446002e+10      RU
# 63      64.0                        Mikecrack   53400000.0    2072.0  1.954208e+10      ES
# 64      65.0               SonyMusicIndiaVEVO   53200000.0    3688.0  3.339955e+10      US
# 65      66.0                 mashabearrussian   52500000.0    2009.0  4.344126e+10      RU
# 66      67.0                    Jess No Limit   52500000.0    2909.0  6.989848e+09      ID
# 67      68.0                      JuegaGerman   51900000.0    2264.0  1.619051e+10      CL
# 68      69.0                     Topper Guild   50800000.0    1070.0  2.107242e+10      US
# 69      70.0            ABS-CBN Entertainment   50800000.0  234889.0  5.627318e+10      PH
# 70      71.0                   Jiocinema Kids   50700000.0    6907.0  2.451383e+10      IN
# 71      72.0                         StarPlus   50400000.0  111513.0  5.450327e+10      IN
# 72      73.0                   Saregama Music   50100000.0    9550.0  2.419139e+10      IN
# 73      74.0        LUCCAS NETO - LICCAS TOON   50100000.0    3028.0  2.969811e+10      BR
# 74      75.0               Masha and The Bear   50100000.0    1735.0  3.013969e+10      US
# 75      76.0                      BETER BOCUK   49900000.0    2915.0  2.803572e+10      TR
# 76      77.0       Real fools shorts official   49500000.0     636.0  2.365040e+10      IN
# 77      78.0                        Bad Bunny   48500000.0     157.0  3.719835e+10      PR
# 78      79.0                       Fernanfloo   48100000.0     547.0  1.072536e+10      SV
# 79      80.0                   Ricis Official   47800000.0    4792.0  8.189252e+09      ID
# 80      81.0                     Ishtar Music   47600000.0    4763.0  2.123373e+10      IN
# 81      82.0                          Badabun   47600000.0   24021.0  1.989490e+10      MX
# 82      83.0                            shfa2   47500000.0    1857.0  3.041215e+10      AE
# 83      84.0                         MrBeast2   47300000.0     123.0  7.045045e+09      US
# 84      85.0                          Shakira   47300000.0     362.0  3.191152e+10      CO
# 85      86.0                    Anaya Kandhal   47100000.0    1921.0  4.477491e+10      IN
# 86      87.0                            shfa    47100000.0    1193.0  2.789417e+10      AE
# 87      88.0                      Felipe Neto   46900000.0    5310.0  1.822110e+10      BR
# 88      89.0                 Dushyant Kukreja   46700000.0    1334.0  3.003633e+10      IN
# 89      90.0                            ISSEI   46300000.0    3201.0  3.452880e+10      JP
# 90      91.0                         ABP NEWS   46300000.0  433181.0  1.968096e+10      IN
# 91      92.0                 Maria Clara & JP   46200000.0     916.0  3.029314e+10      BR
# 92      93.0                      Alan Walker   46200000.0     676.0  1.499680e+10      NO
# 93      94.0                  Kimberly Loaiza   46100000.0     314.0  6.893065e+09      MX
# 94      95.0                   MrBeast Gaming   46000000.0     141.0  8.387527e+09      US
# 95      96.0                    Alfredo Larin   46000000.0    1831.0  3.951888e+10      SV
# 96      97.0                       Voce Sabia   46000000.0    1714.0  8.180068e+09      BR
# 97      98.0                       Katy Perry   45600000.0     170.0  2.761685e+10      US
# 98      99.0                    Speed Records   45500000.0   11880.0  3.058744e+10      IN
# 99     100.0                            Zhong   45500000.0    1861.0  1.799816e+10      US
# 100      NaN                              NaN          NaN       NaN           NaN     NaN

# %%
# Display first 5 rows of the dataset
youtube.head()
# Out:
#    Ranking                  Username  Subscribers   Uploads         Views  \
# 0      1.0                   MrBeast  336000000.0     838.0  6.685363e+10
# 1      2.0                  T-Series  281000000.0   22313.0  2.772428e+11
# 2      3.0  Cocomelon-Nursery Rhymes  186000000.0    1370.0  1.943618e+11
# 3      4.0            Youtube Movies  185000000.0       0.0  0.000000e+00
# 4      5.0                 Set India  180000000.0  148727.0  1.727090e+11
#
#   Country
# 0      US
# 1      IN
# 2      US
# 3     NaN
# 4      IN

# %%
# Display last 5 rows of the dataset
youtube.tail()
# Out:
#      Ranking       Username  Subscribers  Uploads         Views Country
# 96      97.0     Voce Sabia   46000000.0   1714.0  8.180068e+09      BR
# 97      98.0     Katy Perry   45600000.0    170.0  2.761685e+10      US
# 98      99.0  Speed Records   45500000.0  11880.0  3.058744e+10      IN
# 99     100.0          Zhong   45500000.0   1861.0  1.799816e+10      US
# 100      NaN            NaN          NaN      NaN           NaN     NaN

# %%
# Display basic information of the dataset
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ranking      100 non-null    float64
#  1   Username     100 non-null    object
#  2   Subscribers  100 non-null    float64
#  3   Uploads      100 non-null    float64
#  4   Views        100 non-null    float64
#  5   Country      94 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 4.9+ KB

# %%
# Display summary statistic
youtube.describe()
# Out:
#           Ranking   Subscribers        Uploads         Views
# count  100.000000  1.000000e+02     100.000000  1.000000e+02
# mean    50.500000  7.323800e+07   25681.220000  4.054367e+10
# std     29.011492  4.449087e+07   72524.113223  4.033800e+10
# min      1.000000  4.550000e+07       0.000000  0.000000e+00
# 25%     25.750000  5.005000e+07     717.250000  1.964624e+10
# 50%     50.500000  5.995000e+07    1891.000000  3.078494e+10
# 75%     75.250000  7.447500e+07    7028.000000  4.472049e+10
# max    100.000000  3.360000e+08  433181.000000  2.772428e+11

# %%
# Checking for missing values
missing_values = youtube.isnull().sum()
missing_values
# Out:
# Ranking        1
# Username       1
# Subscribers    1
# Uploads        1
# Views          1
# Country        7
# dtype: int64

# %%
# Drop rows with all missing values(if any)
youtube.dropna(how='all',inplace=True)

# %%
# Checking for duplicates
duplicates = youtube.duplicated().sum()
duplicates
# Out:
# 0

# %%
# Drop duplicates
if duplicates > 0:
    youtube.drop_duplicates(inplace=True)

# %% [markdown]
# # Correlation Analysis
# Correlation Analysis is a technique used to measure the relationship between two or more numerical variables. it helps determine if an increase or decrease in one variable is associated with an increase or decrease in another.

# %%
numeric_data = youtube.select_dtypes(include=['float64', 'int64'])

# %%
# Correalation can only be done with numbers not strings
plt.figure(figsize=(12,8))
sns.heatmap(numeric_data.corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Distribution of Uploads
# The Distribution of Uploads refers to how the number of uploads by YouTube channels is spread out across the entire dataset.
# - When you plot the distribution of uploads (using a histogram), you are visualizing:
# - How frequently certain upload counts appear.
# - The shape of the distribution (e.g., normal, skewed, etc.).
# - The range of uploads, from channels with few uploads to those with massive uploads.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(youtube['Uploads'],bins=30,kde=True)
plt.title('Distribution of Uploads')
plt.xlabel('Number of Uploads')
plt.ylabel('Frequency')
plt.show()

# %%
# Checking column names
print('Column Names:',youtube.columns.tolist())
# Out:
# Column Names: ['Ranking', 'Username', 'Subscribers', 'Uploads', 'Views', 'Country']

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# EDA (Exploratory Data Analysis) is the process of examining and visualizing a dataset to discover patterns, identify anomalies, test hypotheses, and check assumptions using statistical and graphical methods. The primary objectives of EDA are:
#
# - Understanding Data Structure: Learning about the dataset's variables, their types, and general statistics.
#
# - Data Cleaning: Handling missing values, duplicates, and incorrect data entries.
#
# - Identifying Patterns: Finding trends, correlations, or distributions within the data.
#
# - Hypothesis Generation: Creating potential relationships or insights for further analysis.
#
# - Data Visualization: Using graphs, charts, and plots to present findings effectively.

# %% [markdown]
# # 1. Top 10 Most Subscribed Channels:

# %%
# Displays the top 10 channels with the highest number of subscribers.
top_subs = youtube.nlargest(10, 'Subscribers')
print('\nTop 10 Most Subscribed Channels:')
print(top_subs[['Username','Subscribers']])
# Out:
# Top 10 Most Subscribed Channels:
#                    Username  Subscribers
# 0                   MrBeast  336000000.0
# 1                  T-Series  281000000.0
# 2  Cocomelon-Nursery Rhymes  186000000.0
# 3            Youtube Movies  185000000.0
# 4                 Set India  180000000.0
# 5               Vlad & Niki  129000000.0
# 6           Kids Diana Show  128000000.0
# 7               Like Nastya  124000000.0
# 8                     Music  121000000.0
# 9         Zee Music Company  112000000.0

# %%
# Plotting the top 10 most subsribed channels
plt.figure(figsize=(12, 6))
plt.bar(top_subs['Username'], top_subs['Subscribers'], color='orange')
plt.xticks(rotation=45)
plt.title('Top 10 Most Subscribed Channels')
plt.xlabel('Channels')
plt.ylabel('Subscribers')

# Adding data labels
for i, v in enumerate(top_subs['Subscribers']):
    plt.text(i,v+0.01 * v,str(v), ha='center')
plt.show()

# %%
# The relationship between Subscribers and Viewers:
# Scatter plot
plt.figure(figsize=(10,6))
sns.scatterplot(x=youtube['Subscribers'],y=youtube['Views'])

# Labelsnand Title
plt.xlabel('Subscribers')
plt.ylabel('Views')
plt.title('Relationship between Subscribers and Views')

# Show plot
plt.show()

# %%
# if the points form an upward trend it means the subscribers leads to more views
# if it is randomly scattered it means there is no strong correlation between Subscribers & Views
# when there is a cluster of points , it means there is a positive correlation

# %%
correlation= youtube['Subscribers'].corr(youtube['Views'])
print (f"correlation efficient: {correlation}")

# A value close to 1 strong positive correlation
# A value close to 0 weak or no correlation
# A value close to -1 strong negative correlation
# Out:
# correlation efficient: 0.6360606485061654

# %%
# Top 10 Channels with the Highest Views:
top_10_channels = youtube.sort_values(by= "Views", ascending =False).head(10)

# Display the result
print (top_10_channels[['Username','Views']])
# Out:
#                     Username         Views
# 1                   T-Series  2.772428e+11
# 2   Cocomelon-Nursery Rhymes  1.943618e+11
# 4                  Set India  1.727090e+11
# 14                  Sony SAB  1.231728e+11
# 6            Kids Diana Show  1.089879e+11
# 7                Like Nastya  1.081285e+11
# 5                Vlad & Niki  9.929150e+10
# 18                    Zee TV  9.756699e+10
# 11                       WWE  9.016718e+10
# 35             Toys & Colors  8.239180e+10

# %%
# plot the Column chart 
plt.figure(figsize= (12,6))
plt.bar(top_10_channels["Username"], top_10_channels["Views"], color="royalblue")

# customize the chart
plt.xticks(rotation=45, ha= "right") # Rotate channel names for better readability
plt.ylabel("Views")
plt.xlabel("Username")
plt.title("Top 10 youtube channels with highest views")
plt.grid(axis= "y", linestyle="--", alpha=0.7)

# show the plot
plt.show()

# %%
# Top 10 Channels with the Highest Uploads:
top_10_channels = youtube.sort_values(by= "Uploads", ascending =False).head(10)

# Display the result
print (top_10_channels[['Username','Uploads']])
# Out:
#                  Username   Uploads
# 90               ABP NEWS  433181.0
# 34                Aaj Tak  415087.0
# 69  ABS-CBN Entertainment  234889.0
# 18                 Zee TV  190672.0
# 22              Colors TV  179052.0
# 50         ARY Digital HD  155545.0
# 41            HAR PAL GEO  152148.0
# 4               Set India  148727.0
# 71               StarPlus  111513.0
# 14               Sony SAB   94136.0

# %%
# plot the Column chart 
plt.figure(figsize= (12, 6))
plt.barh(top_10_channels["Username"], top_10_channels["Uploads"], color="royalblue")

# customize the chart
plt.gca().invert_yaxis() # Rotate channel names for better readability
plt.ylabel("Uploads")
plt.xlabel("Username")
plt.title("Top 10 youtube channels with highest Uploads")
plt.grid(axis="y",linestyle="--", alpha=0.7)

# show the plot
plt.show()

# %%
# Top 10 Countries by views, Subscribers, and Uploads
country_stats= youtube.groupby("Country").sum()
country_stats
# Out:
#          Ranking                                           Username  \
# Country
# AE         204.0                ZAMZAM ELECTRONIC TRADINGshfa2shfa
# AR          96.0                        El Reino InfantilAlejo lgoa
# BR         388.0  Canal KondzillaLUCCAS NETO - LICCAS TOONFelipe...
# CA          26.0                                      Justin Bieber
# CL          68.0                                        JuegaGerman
# CO          85.0                                            Shakira
# ES          64.0                                          Mikecrack
# GB          59.0                                         Ed Sheeran
# ID         147.0                        Jess No LimitRicis Official
# IN        1301.0  T-SeriesSet IndiaZee Music CompanyGoldminesSon...
# IT          57.0                                          PANDA BOL
# JP         101.0                                     PewDiePieISSEI
# KR          88.0                BlackpinkBANGTANTYHYBE LABELSKIMPRO
# MX         281.0  Fede VigevaniYOLO AVENTURASBadabunKimberly Loaiza
# NO          93.0                                        Alan Walker
# PH          70.0                              ABS-CBN Entertainment
# PK          93.0                          HAR PAL GEOARY Digital HD
# PR          78.0                                          Bad Bunny
# PT          29.0                                       UR.Cristiano
# RU         129.0                         Get Moviesmashabearrussian
# SV         175.0                            FernanflooAlfredo Larin
# TR          76.0                                        BETER BOCUK
# US        1233.0  MrBeastCocomelon-Nursery RhymesVlad & NikiKids...
#
#           Subscribers    Uploads         Views
# Country
# AE       1.640000e+08    22274.0  9.254359e+10
# AR       1.230000e+08     2825.0  8.429834e+10
# BR       2.567000e+08    13982.0  1.253161e+11
# CA       7.440000e+07      249.0  3.363673e+10
# CL       5.190000e+07     2264.0  1.619051e+10
# CO       4.730000e+07      362.0  3.191152e+10
# ES       5.340000e+07     2072.0  1.954208e+10
# GB       5.560000e+07      538.0  3.342412e+10
# ID       1.003000e+08     7701.0  1.517910e+10
# IN       2.175600e+09  1759190.0  1.566694e+12
# IT       5.590000e+07     1143.0  2.524301e+10
# JP       1.563000e+08     8001.0  6.398273e+10
# KR       3.243000e+08     9110.0  1.556593e+11
# MX       2.102000e+08    28425.0  6.418835e+10
# NO       4.620000e+07      676.0  1.499680e+10
# PH       5.080000e+07   234889.0  5.627318e+10
# PK       1.228000e+08   307693.0  1.235406e+11
# PR       4.850000e+07      157.0  3.719835e+10
# PT       7.170000e+07       80.0  7.212288e+08
# RU       1.061000e+08     5477.0  7.790128e+10
# SV       9.410000e+07     2378.0  5.024423e+10
# TR       4.990000e+07     2915.0  2.803572e+10
# US       2.241800e+09    74561.0  1.215223e+12

# %%
# Get the top 5 countries based on Views, Subscribers, and Uploads
top_5_views = country_stats.sort_values(by="Views",ascending=False).head(5)
top_5_views
# Out:
#          Ranking                                           Username  \
# Country
# IN        1301.0  T-SeriesSet IndiaZee Music CompanyGoldminesSon...
# US        1233.0  MrBeastCocomelon-Nursery RhymesVlad & NikiKids...
# KR          88.0                BlackpinkBANGTANTYHYBE LABELSKIMPRO
# BR         388.0  Canal KondzillaLUCCAS NETO - LICCAS TOONFelipe...
# PK          93.0                          HAR PAL GEOARY Digital HD
#
#           Subscribers    Uploads         Views
# Country
# IN       2.175600e+09  1759190.0  1.566694e+12
# US       2.241800e+09    74561.0  1.215223e+12
# KR       3.243000e+08     9110.0  1.556593e+11
# BR       2.567000e+08    13982.0  1.253161e+11
# PK       1.228000e+08   307693.0  1.235406e+11

# %%
# Get the top 5 countries based on Views, Subscribers, and Uploads
top_5_views = country_stats.sort_values(by="Views",ascending=False).head(5)
top_5_subscribers = country_stats.sort_values(by="Subscribers",ascending=False).head(5)
top_5_uploads = country_stats.sort_values(by="Uploads",ascending=False).head(5)

# Plot the results
fig,axes = plt.subplots(1,3, figsize= (18,5))
#views
axes[0].bar(top_5_views.index,top_5_views["Views"], color='purple')
axes[0].set_title('Top 5 countries by Views')
axes[0].set_ylabel("Total Views")
axes[0].set_xticklabels(top_5_views.index, rotation =45)

#Subscribers
axes[1].bar(top_5_subscribers.index,top_5_subscribers["Subscribers"], color='green')
axes[1].set_title('Top 5 countries by Subscribers')
axes[1].set_ylabel("Total Subscribers")
axes[1].set_xticklabels(top_5_views.index, rotation =45)

#Uploads
axes[2].bar(top_5_uploads.index,top_5_uploads["Uploads"], color='blue')
axes[2].set_title('Top 5 countries by Uploads')
axes[2].set_ylabel("Total Uploads")
axes[2].set_xticklabels(top_5_views.index, rotation =45)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16832\1897442388.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels(top_5_views.index, rotation =45)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16832\1897442388.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels(top_5_views.index, rotation =45)
# C:\Users\HP\AppData\Local\Temp\ipykernel_16832\1897442388.py:24: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[2].set_xticklabels(top_5_views.index, rotation =45)
# [Text(0, 0, 'IN'),
#  Text(1, 0, 'US'),
#  Text(2, 0, 'KR'),
#  Text(3, 0, 'BR'),
#  Text(4, 0, 'PK')]
